# %%
import sys
import os
import teanets as tea
import teanets.analytics
import teanets.teaplot as teaplot
sys.path.insert(0, os.path.abspath('..'))
# !pip install -q git+https://github.com/MassimoStel/TEA_Networks.git

# %%
text = """Alex and Ben care for animals and love hiking through national parks. However, they dislike shopping malls because they are overwhelming and chaotic."""

# %%
svo = tea.extract_svos_from_text(text)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00, 197.60 examples/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.94it/s]
# [nltk_data] Downloading package wordnet to /home/seb/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
display(svo)
# Out:
#              Node 1     TEA                 Node 2    TEA2  \
# 0              alex   Agent                   care   Event
# 1               ben   Agent                   care   Event
# 2              care   Event             for animal  Target
# 3              alex   Agent                    ben   Agent
# 4              alex   Agent              love hike   Event
# 5               ben   Agent              love hike   Event
# 6         love hike   Event  through national park  Target
# 7              alex   Agent                    ben   Agent
# 8              alex   Agent        however dislike   Event
# 9               ben   Agent        however dislike   Event
# 10  however dislike   Event          shopping mall  Target
# 11             alex   Agent                    ben   Agent
# 12    shopping mall   Agent                     be   Event
# 13               be   Event           overwhelming  Target
# 14               be   Event                chaotic  Target
# 15     overwhelming  Target                chaotic  Target
#
#                                            Hypergraph  Semantic-Syntactic  \
# 0   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 1   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 2   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 3   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 4   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 5   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 6   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 7   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 8   [[('alex', []), ('ben', [])], ['however dislik...                   0
# 9   [[('alex', []), ('ben', [])], ['however dislik...                   0
# 10  [[('alex', []), ('ben', [])], ['however dislik...                   0
# 11  [[('alex', []), ('ben', [])], ['however dislik...                   0
# 12  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
# 13  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
# 14  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
# 15  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
#
#     svo_id  passive_approx  is_passive
# 0        0               0           0
# 1        0               0           0
# 2        0               0           0
# 3        0               0           0
# 4        1               0           0
# 5        1               0           0
# 6        1               0           0
# 7        1               0           0
# 8        2               0           0
# 9        2               0           0
# 10       2               0           0
# 11       2               0           0
# 12       3               0           0
# 13       3               0           0
# 14       3               0           0
# 15       3               0           0

# %%
teaplot.plot_svo_graph(
    svo,
    custom_font=30
)

# %%
# 1. Load TEA Nets from this local repository
from pathlib import Path
import sys

repo_root = Path.cwd().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# 1. Load necessary modules
import teanets as tea
import teanets.analytics

# 2. Extract SVO triplets from text
text = "Alex and Ben care for animals and love hiking through national parks. However, they dislike shopping malls because they are overwhelming and chaotic"
svo = tea.extract_svos_from_text(text)
display(svo)

# 3. Plot the TEA Net
import teanets.teaplot as teaplot
teaplot.plot_svo_graph(svo, custom_font=20)
# Out:
# Map: 100%|██████████| 1/1 [00:00<00:00, 369.02 examples/s]
# Inference: 100%|██████████| 1/1 [00:00<00:00, 68.24it/s]
#              Node 1     TEA                 Node 2    TEA2  \
# 0              alex   Agent                   care   Event
# 1               ben   Agent                   care   Event
# 2              care   Event             for animal  Target
# 3              alex   Agent                    ben   Agent
# 4              alex   Agent              love hike   Event
# 5               ben   Agent              love hike   Event
# 6         love hike   Event  through national park  Target
# 7              alex   Agent                    ben   Agent
# 8              alex   Agent        however dislike   Event
# 9               ben   Agent        however dislike   Event
# 10  however dislike   Event          shopping mall  Target
# 11             alex   Agent                    ben   Agent
# 12    shopping mall   Agent                     be   Event
# 13               be   Event           overwhelming  Target
# 14               be   Event                chaotic  Target
# 15     overwhelming  Target                chaotic  Target
#
#                                            Hypergraph  Semantic-Syntactic  \
# 0   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 1   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 2   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 3   [[('alex', []), ('ben', [])], ['care'], [('for...                   0
# 4   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 5   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 6   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 7   [[('alex', []), ('ben', [])], ['love hike'], [...                   0
# 8   [[('alex', []), ('ben', [])], ['however dislik...                   0
# 9   [[('alex', []), ('ben', [])], ['however dislik...                   0
# 10  [[('alex', []), ('ben', [])], ['however dislik...                   0
# 11  [[('alex', []), ('ben', [])], ['however dislik...                   0
# 12  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
# 13  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
# 14  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
# 15  [[('shopping mall', [])], ['be'], [('overwhelm...                   0
#
#     svo_id  passive_approx  is_passive
# 0        0               0           0
# 1        0               0           0
# 2        0               0           0
# 3        0               0           0
# 4        1               0           0
# 5        1               0           0
# 6        1               0           0
# 7        1               0           0
# 8        2               0           0
# 9        2               0           0
# 10       2               0           0
# 11       2               0           0
# 12       3               0           0
# 13       3               0           0
# 14       3               0           0
# 15       3               0           0
